# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x= [2,2,4,6,87]
y=[4,5,3,4,2]

# %%
plt.pie(x,labels=['a','b','c','c','e'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1705acc79e0>,
# ...
#  [Text(1.0978721568698198, 0.0683866008075404, 'a'),
#   Text(1.0808987732492235, 0.20410252812820384, 'b'),
#   Text(1.024258469112138, 0.4011166768560739, 'c'),
#   Text(0.8523427996476268, 0.6953500930386404, 'c'),
#   Text(-0.997339863301535, -0.4640185309550424, 'e')])

# %%
x= [2,2,4,6,10]
y=[4,5,3,4,2]

# %%
plt.stairs(x)
