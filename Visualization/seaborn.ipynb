# %%
import seaborn as sns

# %%
iris= sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['sepal_width'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'],y=iris['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
#  for some cateogy of flowers sepal length increasing but not petal length but for others both are increasing

# %%
sns.scatterplot(x=iris['petal_width'],y=iris['petal_length'])
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.displot(iris['sepal_length'])

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tips.total_bill , y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x=tips.total_bill,y=tips.tip , data =tips , hue='smoker') # gets categories or groups from smoker assign each one a diff color and represent

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(x=tips.total_bill,y=tips.tip , data =tips , hue='size')

# %%
sns.relplot(x=tips.total_bill,y=tips.tip , data =tips , hue='size',style='size')

# %%
sns.relplot(x=tips.total_bill,y=tips.tip , data =tips , hue='time', style='size')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day' , y='total_bill' , data =tips)

# %%
print(tips.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.catplot(x='smoker' , y='tip' , data =tips)

# %%
sns.jointplot(x=tips.total_bill , y=tips.tip , data = tips)

# %% [markdown]
# scatter plot in mid
# total bill histogram on top
# tip histogram on right

# %%
sns.pairplot(tips)

# %%
sns.jointplot( tips)

# %% [markdown]
# KDE Plots on the Margins
#
#     Top KDE (for total_bill):
#         The shaded area at the top shows the density of total_bill values.
#         It’s roughly bell-shaped, indicating that most bills are between 10 and 30, with a peak around 15–20. The distribution has a long right tail, meaning there are fewer high-value bills (e.g., above 50).
#     Right KDE (for tip and size):
#         The blue line represents the distribution of total_bill (matching the top KDE but rotated).
#         The orange line shows the distribution of tip amounts:
#             Tips are mostly between 0 and 10, with a peak around 2–3.
#             There’s a long right tail, indicating some larger tips (e.g., above 5).
#         The green line shows the distribution of size:
#             Party sizes are discrete (likely integers like 1, 2, 3, etc.).
#             The KDE shows peaks at sizes like 2, 3, and 4, indicating these are the most common party sizes.
#             The distribution drops off sharply after size 6, meaning larger parties are rare.
#
# 5. What the Graph Tells Us
#
# This graph is likely part of an exploratory data analysis (EDA) using the famous "tips" dataset (commonly used in Seaborn tutorials), which contains data about restaurant bills, tips, and party sizes. Here’s what we can infer:
#
#     Total Bill Distribution: Most bills are relatively small (under 50), with a few outliers above 200.
#     Tip Distribution: Tips are generally small (most under 5), but there are some larger tips corresponding to higher bills.
#     Party Size: Most dining groups are small (2–4 people), with very few groups larger than 6.
#     Relationship Insight: Since the scatter plot aligns tip and size with total_bill, you can visually see that higher bills (on the right side of the x-axis) tend to have higher tips (orange dots) and sometimes larger party sizes (green dots), though this is not a formal correlation analysis.
#
# 6. Why "None" on the Y-Axis?
#
# The "None" label on the y-axis suggests that this is not a traditional scatter plot. In Seaborn, this kind of plot might be created using a combination of stripplot, swarmplot, or a jointplot with modifications. The y-axis is likely used to spread out the points for better visualization rather than to represent a specific variable. In a jointplot, the marginal KDEs (top and right) are often used to show the distributions of the variables, while the central plot shows their relationship—or in this case, just the spread of points against one variable (total_bill).
# 7. Potential Code to Generate This Plot
#
# This graph might have been created using Seaborn in Python. Here’s a speculative example of how this could be done using the "tips" dataset:
